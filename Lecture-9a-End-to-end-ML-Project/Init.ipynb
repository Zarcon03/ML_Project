# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 18.1 MB/s eta 0:00:00
# Collecting mlxtend
#   Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 108.5 MB/s eta 0:00:00
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: joblib>=1.1.1 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: numpy>=1.17.3 in /root/venv/lib/python3.9/site-packages (from imbalanced-learn->-r ./requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /root/venv/lib/python3.9/site-packages (from mlxtend->-r ./requirements.txt (line 2)) (3.6.3)
# Requirement already satisfied: pandas>=0.24.2 in /root/venv/lib/python3.9/site-packages (from mlxtend->-r ./requirements.txt (line 2)) (2.1.4)
# Collecting scikit-learn>=1.0.2
#   Downloading scikit_learn-1.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 135.6 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from missingno->-r ./requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (24.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (4.55.2)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend->-r ./requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend->-r ./requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend->-r ./requirements.txt (line 2)) (1.17.0)
# Installing collected packages: scikit-learn, mlxtend, imbalanced-learn, missingno
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
# Successfully installed imbalanced-learn-0.12.4 missingno-0.5.2 mlxtend-0.23.3 scikit-learn-1.6.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=78def080-3b0d-4970-bb05-f9302776d10d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
